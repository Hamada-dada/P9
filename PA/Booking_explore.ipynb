# %%
# %%
import pandas as pd
from pathlib import Path

# --- Load Bookplan data ---
BOOK_PATH = Path(r"C:\Users\kfq6\Documents\Data\Bookinger.xlsx")  # update path if needed
book = pd.read_excel(BOOK_PATH, engine="openpyxl")

# --- Standard clean-up ---
book.columns = book.columns.str.strip()
book["Angaaende"] = book["Angaaende"].astype(str).str.lower().str.strip()

# --- Filter for Sammedagsscreening (any mention of 'screening') ---
screening = book[book["Angaaende"].str.contains("screening", na=False)]

# --- Count unique patients (DW_EK_Borger) ---
n_patients = screening["DW_EK_Borger"].nunique()
print(f"Number of unique patients with a 'sammedagsscreening': {n_patients}")

# --- Optional summary table: number of screenings per patient ---
screening_counts = (
    screening.groupby("DW_EK_Borger")
    .size()
    .reset_index(name="n_screenings")
    .sort_values("n_screenings", ascending=False)
)

print("\nTop 10 patients by number of sammedagsscreeninger:")
print(screening_counts.head(10))

# --- Save to file if you like ---
out_path = Path(r"C:\Users\kfq6\Documents\Data\Bookplan_sammedagsscreening.xlsx")
screening.to_excel(out_path, index=False)
print("\nFiltered screening data saved to:", out_path)
# Out:
# c:\Python\Python311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Number of unique patients with a 'sammedagsscreening': 2342
#
# Top 10 patients by number of sammedagsscreeninger:
#       DW_EK_Borger  n_screenings
# 901         536408            55
# 1690        974335            45
# 77           55343            43
# 1693        975238            42
# 1745        997028            36
# 1406        808613            36
# 16           11946            36
# 538         325019            36
# 283         175923            36
# 354         212648            36
#
# Filtered screening data saved to: C:\Users\kfq6\Documents\Data\Bookplan_sammedagsscreening.xlsx

# %%
# --- (optional) keep only completed/active bookings ---
if "BookingStatusTekst" in screening.columns:
    screening = screening[screening["BookingStatusTekst"].isin(["Afviklet", "Booket"])]

# --- robust meeting datetime + date ---
def _parse_meeting_dt(row, dcol="Dato_MoedeDato", tcol="Klok_MoedeTid"):
    d = pd.to_datetime(row.get(dcol), errors="coerce", dayfirst=True)
    if pd.isna(d):
        return pd.NaT
    t_raw = row.get(tcol)
    if pd.isna(t_raw):
        return d
    t_str = str(t_raw).strip()
    for fmt in ("%H:%M:%S", "%H:%M", "%H%M%S", "%H%M"):
        try:
            return pd.to_datetime(f"{d.date()} {pd.to_datetime(t_str, format=fmt).time()}")
        except Exception:
            continue
    return d

screening = screening.copy()
screening["meeting_dt"] = screening.apply(_parse_meeting_dt, axis=1)
screening["meeting_date"] = screening["meeting_dt"].dt.normalize()

# --- collapse to ONE "real screening" per patient per day ---
screening_days = (
    screening
    .groupby(["DW_EK_Borger", "meeting_date"], dropna=False)
    .agg(
        n_bookings=("DW_EK_Borger", "size"),
        first_time=("meeting_dt", "min"),
        last_time=("meeting_dt", "max"),
    )
    .reset_index()
)

# --- per-patient counts overall and in rolling windows (1y, 5y) ---
END_DATE = pd.Timestamp.today().normalize()
cut1 = END_DATE - pd.Timedelta(days=365)
cut5 = END_DATE - pd.Timedelta(days=5*365)

per_patient = (
    screening_days
    .assign(
        in_1y=lambda d: d["meeting_date"] >= cut1,
        in_5y=lambda d: d["meeting_date"] >= cut5,
    )
    .groupby("DW_EK_Borger", as_index=False)
    .agg(
        n_screenings_total=("meeting_date", "nunique"),
        n_screenings_1y=("in_1y", "sum"),
        n_screenings_5y=("in_5y", "sum"),
        first_screening=("meeting_date", "min"),
        last_screening=("meeting_date", "max"),
    )
    .sort_values("n_screenings_total", ascending=False)
)

print("Real screenings (unique patient-days):", screening_days.shape[0])
print("Unique patients with ≥1 screening:", per_patient.shape[0])
print(per_patient.head(10))

# --- save (optional) ---
screening_days.to_excel(r"C:\Users\kfq6\Documents\Data\Bookplan_screening_days.xlsx", index=False)
per_patient.to_excel(r"C:\Users\kfq6\Documents\Data\Bookplan_screening_per_patient.xlsx", index=False)
# Out:
# Real screenings (unique patient-days): 4901
# Unique patients with ≥1 screening: 2090
#       DW_EK_Borger  n_screenings_total  n_screenings_1y  n_screenings_5y  \
# 1693       1080018                   6                1                6
# 47           34391                   6                1                6
# 132         100865                   5                0                5
# 1356        866144                   5                1                5
# 462         309158                   5                1                5
# 750         506569                   5                3                5
# 1857       1168177                   5                2                5
# 1878       1181071                   5                1                5
# 1900       1192261                   5                1                5
# 1912       1196616                   5                2                5
#
#      first_screening last_screening
# 1693      2022-05-31     2025-06-18
# 47        2022-11-11     2025-02-07
# 132       2022-09-07     2024-08-19
# 1356      2022-05-31     2025-06-27
# 462       2022-06-01     2025-02-27
# 750       2022-05-19     2025-03-18
# 1857      2022-10-26     2024-12-18
# 1878      2022-09-27     2024-11-21
# 1900      2022-05-25     2024-12-04
# 1912      2023-01-20     2025-06-11

# %%
# %%
import pandas as pd
from pathlib import Path

# --- Load Bookplan data ---
BOOK_PATH = Path(r"C:\Users\kfq6\Documents\Data\Bookinger.xlsx")
book = pd.read_excel(BOOK_PATH, engine="openpyxl")

# --- Basic cleaning ---
book.columns = book.columns.str.strip()
book["Angaaende"] = book["Angaaende"].astype(str).str.lower().str.strip()

# --- Filter for Sammedagsscreening only ---
samedag = book[book["Angaaende"].str.contains("sammedagsscreening", na=False)]

# --- Keep only completed or booked visits ---
if "BookingStatusTekst" in samedag.columns:
    samedag = samedag[samedag["BookingStatusTekst"].isin(["Afviklet", "Booket"])]

# --- Parse meeting datetime ---
def _parse_meeting_dt(row, dcol="Dato_MoedeDato", tcol="Klok_MoedeTid"):
    d = pd.to_datetime(row.get(dcol), errors="coerce", dayfirst=True)
    if pd.isna(d):
        return pd.NaT
    t_raw = row.get(tcol)
    if pd.isna(t_raw):
        return d
    t_str = str(t_raw).strip()
    for fmt in ("%H:%M:%S", "%H:%M", "%H%M%S", "%H%M"):
        try:
            return pd.to_datetime(f"{d.date()} {pd.to_datetime(t_str, format=fmt).time()}")
        except Exception:
            continue
    return d

samedag = samedag.copy()
samedag["meeting_dt"] = samedag.apply(_parse_meeting_dt, axis=1)
samedag["meeting_date"] = samedag["meeting_dt"].dt.normalize()

# --- Collapse multiple same-day bookings into one real Sammedagsscreening ---
samedag_days = (
    samedag
    .groupby(["DW_EK_Borger", "meeting_date"], dropna=False)
    .agg(
        n_bookings=("DW_EK_Borger", "size"),
        first_time=("meeting_dt", "min"),
        last_time=("meeting_dt", "max"),
    )
    .reset_index()
)

# --- Per-patient summary with 1-year and 5-year windows ---
END_DATE = pd.Timestamp.today().normalize()
cut1 = END_DATE - pd.Timedelta(days=365)
cut5 = END_DATE - pd.Timedelta(days=5*365)

per_patient = (
    samedag_days
    .assign(
        in_1y=lambda d: d["meeting_date"] >= cut1,
        in_5y=lambda d: d["meeting_date"] >= cut5,
    )
    .groupby("DW_EK_Borger", as_index=False)
    .agg(
        n_sammedag_total=("meeting_date", "nunique"),
        n_sammedag_1y=("in_1y", "sum"),
        n_sammedag_5y=("in_5y", "sum"),
        first_sammedag=("meeting_date", "min"),
        last_sammedag=("meeting_date", "max"),
    )
    .sort_values("n_sammedag_total", ascending=False)
)

print("Total unique Sammedagsscreeninger (patient-day):", samedag_days.shape[0])
print("Unique patients with ≥1 Sammedagsscreening:", per_patient.shape[0])
print(per_patient.head(10))

# --- Save optional outputs ---
samedag_days.to_excel(r"C:\Users\kfq6\Documents\Data\Bookplan_sammedag_days.xlsx", index=False)
per_patient.to_excel(r"C:\Users\kfq6\Documents\Data\Bookplan_sammedag_per_patient.xlsx", index=False)
# Out:
# c:\Python\Python311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Total unique Sammedagsscreeninger (patient-day): 4596
# Unique patients with ≥1 Sammedagsscreening: 2036
#       DW_EK_Borger  n_sammedag_total  n_sammedag_1y  n_sammedag_5y  \
# 1761       1143452                 4              1              4
# 1813       1171734                 4              1              4
# 1140        753640                 4              2              4
# 483         331981                 4              1              4
# 1506        988911                 4              1              4
# 313         215215                 4              1              4
# 804         548785                 4              1              4
# 1133        746643                 4              1              4
# 1714       1117925                 4              1              4
# 468         320724                 4              1              4
#
#      first_sammedag last_sammedag
# 1761     2022-04-01    2025-06-27
# 1813     2022-06-10    2025-09-18
# 1140     2022-10-31    2025-09-24
# 483      2022-04-08    2025-06-30
# 1506     2022-05-06    2025-07-03
# 313      2022-11-15    2025-03-10
# 804      2022-06-23    2025-09-17
# 1133     2022-05-17    2025-07-02
# 1714     2022-06-01    2025-06-25
# 468      2022-03-30    2025-07-02

# %%
# Count unique text values in column "angaaende"

unique_count = book["Angaaende"].nunique()
unique_values = book["Angaaende"].unique()

print(f"Antal unikke værdier i 'angaaende': {unique_count}")
print(unique_values)
# Out:
# Antal unikke værdier i 'angaaende': 6340
# ['diabeteskontrol' 'øjendryp_x0020__x0028_sam_x0029_'
#  'screeningssamtale_x0020_med_x0020_diabetessygeplejerske' ...
#  'fus_x0020_c_x0020_fra_x0020_aleris'
#  'udredning_x0020_amb_x0020_adhd_x0020_60_x0020_min'
#  'sårrevision_x0020_efter_x0020_hjertekirurgi_x0020_-_x0020_sårrevision_x0020_af_x0020_graft_x002f_cikatrice']

# %%
# Count unique text values in column "angaaende"

unique_count = book["ShakTekst_BookendeAfdeling"].nunique()
unique_values = book["ShakTekst_BookendeAfdeling"].unique()

print(f"Antal unikke værdier i 'angaaende': {unique_count}")
print(unique_values)
# Out:
# Antal unikke værdier i 'angaaende': 102
# ['Alb_x0020_Børneområde' 'Alb_x0020_Endokrinologisk_x0020_Område'
#  'Alb_x0020_Fysio-og_x0020_Ergoterapi' 'Alb_x0020_Klinisk_x0020_Biokemi'
#  'Hjr_x0020_Billeddiagnostisk_x0020_afd.'
#  'Alb_x0020_Med.gastroenterologisk_x0020_omr'
#  'Alb_x0020_O-kir_x0020_ambulant' 'Alb_x0020_Røntgen_x0020_Ambulatorium'
#  'Alb_x0020_Nyremedicinsk_x0020_område'
#  'Thy_x0020_Billeddiagnostisk_x0020_afd.'
#  'Alb_x0020_Kardiologisk_x0020_Område'
#  'Hjr_x0020_O-kir_x0020_ambulatorium'
#  'Alb_x0020_Dermatologisk_x0020_Område'
#  'Far_x0020_Klinisk-kemisk_x0020_afd._x0020_Farsø'
#  'Hjr_x0020_Diabetes_x0020_og_x0020_hormonsygdomme' 'Vagtcentralen'
#  'PS_x0020_Klinik_x0020_Syd_x0020_Ambulatorier'
#  'Alb_x0020_Gyn.-obst._x0020_Område'
#  'PS_x0020_Klinik_x0020_Syd_x0020_Musikterapiafd'
#  'Hob_x0020_Medicinsk_x0020_område'
#  'Hjr_x0020_Klinisk_x0020_biokemisk_x0020_afdeling'
#  'Alb_x0020_5._x0020_Afd_x0020__x0028_Smertecenter_x0029_'
#  'Alb_x0020_Øjenområde' 'Alb_x0020_Sexologisk_x0020_Center'
#  'Alb_x0020_Kir_x0020_Gastro._x0020_Område'
#  'Alb_x0020_Neurologisk_x0020_Område'
#  'Frh_x0020_Billeddiagnostisk_x0020_Amb.'
#  'Alb_x0020_Reumatologisk_x0020_Område' 'Alb_x0020_Urologisk_x0020_Område'
#  'Alb_x0020_Klinisk_x0020_neurofys._x0020_amb.'
#  'PS_x0020_BU_x0020_Ambulatorium' 'Far_x0020_O-kir_x0020_Amb.'
#  'Alb_x0020_Audiologisk_x0020_Område' 'Alb_x0020_Forebyggelse'
#  'Alb_x0020_Nuklearmedicinsk_x0020_Amb.'
#  'Alb_x0020_Neurokir._x0020_Område' 'Alb_x0020_Karkirurgisk_x0020_Område'
#  'PS_x0020_Klinik_x0020_Nord_x0020_Ambulatorier'
#  'Alb_x0020_Onkologisk_x0020_Område'
#  'RN_x0020_EBS_x0020_Mamma_x0020_SMS_x0020_Afsnit'
#  'Thy_x0020_Gyn_x0020_Obst_x0020_Område'
#  'Alb_x0020_Akut-_x0020_og_x0020_Traumecenter'
#  'Alb_x0020_Øre-Næse-Halsområde' 'Far_x0020_Medicinsk_x0020_område'
#  'Alb_x0020_Brobyggersygeplejesker_x0020_amb_x0020_-_x0020_AFSNITTET_x0020_ER_x0020_BLEVET_x0020_LUKKET_x002F_Lene_x0020_S._x0020_jan._x0020_2024'
#  'Frh_x0020_O-kir_x0020_ambulatorium'
#  'Alb_x0020_Infektionshygiejnisk_x0020_amb' 'Alb_x0020_Op_x0020_Nord'
#  'PS_x0020_Retspsykiatri_x0020_Ambulatorier'
#  'Alb_x0020_Geriatrisk_x0020_Område' 'Thy_x0020_Medicinsk_x0020_Område'
#  'Frh_x0020_Klinisk_x0020_Biokemisk_x0020_Afdeling'
#  'Thy_x0020_Klinisk_x0020_Biokemisk_x0020_Område'
#  'Ven_x0020_Reumatologisk_x0020_område' 'Frh_x0020_Op_x0020_Vendsyssel'
#  'Alb_x0020_Hæmatologisk_x0020_Område' 'Alb_x0020_Lungemed._x0020_Område'
#  'Hjr_x0020_Kirurgisk_x0020_afd.' 'Hjr_x0020_Urinvejskirurgi'
#  'RHN_x0020_Intern_x0020_Medicin'
#  'Alb_x0020_Plastikkirurgisk_x0020_Område' 'Alb_x0020_Op_x0020_Syd'
#  'Hjr_x0020_Med._x0020_Mave-_x0020_og_x0020_tarmsygdomme'
#  'Alb_x0020_IVF-Klinikken_x0020_gyn.-obs'
#  'Alb_x0020_Hjerte-lungekirurgisk_x0020_afd'
#  'Thy_x0020_Kirurgisk_x0020_Område' 'Alb_x0020_Kæbekirurgisk_x0020_område'
#  'Ven_x0020_Terapiområdet'
#  'Alb_x0020_Arbejds-_x0020_og_x0020_Miljømed._x0020_Omr'
#  'Hob_x0020_Klinisk-kemisk_x0020_afd._x0020_Hobro'
#  'Alb_x0020_Infektionsmedicinsk_x0020_Område' 'Hjr_x0020_hjertemedicinsk'
#  'Thy_x0020_Ortopædkir._x0020_Ambulatorium'
#  'Alb_x0020_Klinisk_x0020_Genetisk_x0020_Område' 'SV_x0020_Diætistenhed'
#  'Alb_x0020_Mammakirurgisk_x0020_Område'
#  'Center_x0020_for_x0020_Sportsmedicin_x0020_og_x0020_Sundhed'
#  'Thy_x0020_Fysioterapi_x0020_Område' 'Alb_x0020_Demensenheden'
#  'Ven_x0020_Gyn.-Obst._x0020_Område' 'Hjr_x0020_Lungemedicinsk'
#  'Thy_x0020_Med_x0020_Kardiologisk_x0020_Amb'
#  'Alb_x0020_Center_x0020_for_x0020_Pårørende_x0020_afs'
#  'Alb_x0020_Gyn_x0020_obst_x0020_hørescreening_x0020_amb'
#  'Alb_x0020_Center_x0020_for_x0020_Funktionelle_x0020_Li' 'Thy_x0020_OPT'
#  'Rehab.Center_x0020_f._x0020_flygtninge_x0020_afs'
#  'Alb_x0020_Op_x0020_Hobro' 'Thy_x002C__x0020_Smertecenter'
#  'Hjr_x0020_Pædiatrisk_x0020_område'
#  'Skagen_x0020_Gigt_x0020_og_x0020_Rygcenter'
#  'Alb_x0020_Anæstesi_x0020_Nord_x0020_Amb'
#  'Alb_x0020_2.Afdeling_x0020__x0028_NOT_x002F_Farsø_x0029_'
#  'PS_x0020_Ældrepsykiatri'
#  'Alb_x0020_Blodb._x0020_og_x0020_klin._x0020_Immun.'
#  'Dialysen_x0020_Aalborg' 'Hjr_x0020_Ældremedicinsk'
#  'RHN_x0020_Palliationsteam'
#  'Thy_x0020_Team_x0020_for_x0020_Lindrende_x0020_Behandling'
#  'Thy_x0020_Dialyse_x0020_Amb.' 'Ven_x0020_Akutmodtagelsen'
#  'Thy_x0020_Amb._x0020_i_x0020_Modtagelsen']

# %%
# Count unique text values in column "angaaende"

unique_count = book["BookingStatusTekst"].nunique()
unique_values = book["BookingStatusTekst"].unique()

print(f"Antal unikke værdier i 'BookingStatusTekst': {unique_count}")
print(unique_values)
# Out:
# Antal unikke værdier i 'BookingStatusTekst': 7
# ['Afviklet' 'Slettet' 'Aflyst' 'Booket' 'Huskeliste' 'Genbooking'
#  'Anmodet']
